# %%
from Dosepy.image import load_multiples
import plotly.express as px

# %%
# Import images
images = [
    "/media/luis/TOMO/Tiff Films/LATI/Film_a_20240711_003.tif",
    "/media/luis/TOMO/Tiff Films/LATI/Film_a_20240711_004.tif",
    "/media/luis/TOMO/Tiff Films/LATI/Film_a_20240711_005.tif",
]

tiff = load_multiples(images)

# %%
px.imshow(tiff.array)

# %%
# Import images including zero
images = [
    "/media/luis/TOMO/Tiff Films/LATI/Film_a_20240711_003.tif",
    "/media/luis/TOMO/Tiff Films/LATI/Film_a_20240711_004.tif",
    "/media/luis/TOMO/Tiff Films/LATI/Film_a_20240711_005.tif",
    "/media/luis/TOMO/Tiff Films/LATI/Film_draw_20240711_001.tif",
]

tiff = load_multiples(images)
px.imshow(tiff.array)

# %%
from Dosepy.tiff2dose import Tiff2DoseM, LUT
from Dosepy.image import ArrayImage, load

# %%
# Compute calibration

files = [
    "/media/luis/TOMO/Tiff Films/EBT4/6NOV24_CAL/CAL20241106_001.tif",
    "/media/luis/TOMO/Tiff Films/EBT4/6NOV24_CAL/CAL20241106_002.tif",
    "/media/luis/TOMO/Tiff Films/EBT4/6NOV24_CAL/CAL20241106_003.tif",
]

cal_image = load_multiples(files)
cal = LUT(cal_image)
cal.set_central_rois(size = (180, 8))
cal.set_doses([0, 0.5, 1, 2, 4, 6, 8, 10])
cal.plot_rois()
cal.set_beam_profile("/media/luis/TOMO/Tiff Films/BeamProfile.csv")
cal.compute_lateral_lut(filter = 5)

# %%
to_dose_manager: Tiff2DoseM = Tiff2DoseM()

# %%
tiff.set_labeled_films_and_filters()

# %%
px.imshow(tiff.labeled_films)

# %% [markdown]
# #### Remove objects that are not films

# %%
#tiff.labeled_films[tiff.labeled_films == 1] = 0
#tiff.labeled_films[tiff.labeled_films == 3] = 0

tiff.array[tiff.labeled_films == 1] = 0
tiff.array[tiff.labeled_films == 3] = 0

# %%
tiff.

# %%
px.imshow(tiff.labeled_films)

# %%
to_dose_manager.get_dose(
    img = tiff,
    format = "RP",
    lut = cal,
)
# Out:
# The film is not in the center of the scaner.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 to_dose_manager.get_dose(
#       2     img = tiff,
#       3     format = "RP",
#       4     lut = cal,
#       5 )
#
# File ~/GH/Dosepy/src/Dosepy/tiff2dose.py:93, in Tiff2DoseM.get_dose(self, img, format, lut)
#      73 """
#      74 Get the dose array from a tiff image.
#      75
#    (...)     90     The dose distribution
#      91 """
#      92 self._set_dose_converter(format)
# ---> 93 return self.dose_converter.convert2dose(img, lut)
#
# File ~/GH/Dosepy/src/Dosepy/tiff2dose.py:347, in PolynomialDoseConverter.convert2dose(self, img, lut)
#     344 if not self.check_optical_filters(img, lut):
#     345     print("TODO")
# --> 347 lateral_intensities_for_zero_dose, positions = self._get_lateral_intensities_for_zero_dose(
#     348     img, lut, channel=self.channel
#     349 )
#     351 dose_array = np.empty(img.array[:, :, CHANNEL_IDX[self.channel]].shape)
#     352 width_in_pixels = img.shape[1]
#
# File ~/GH/Dosepy/src/Dosepy/tiff2dose.py:280, in DoseConverter._get_lateral_intensities_for_zero_dose(self, img, lut, channel)
#     276 relative_intensities = lateral_intensities/reference_intensity
#     278 # Get the intensity of the unexposed film that was scanned togheter
#     279 # with the film to be converted to dose
# --> 280 zero_dose_intensity_at_center, roi = self._get_zero_dose_intensity(
#     281     img,
#     282     channel,
#     283     at_zero_position = True,
#     284     )
#     286 # Compute lateral intensities for film with zero dose
#     287 zero_dose_intensities = zero_dose_intensity_at_center * relative_intensities
#
# File ~/GH/Dosepy/src/Dosepy/tiff2dose.py:192, in DoseConverter._get_zero_dose_intensity(self, img, channel, at_zero_position)
#     190 if not min_col < img_center_y < max_col:
#     191     print("The film is not in the center of the scaner.")
# --> 192     raise ValueError("The film is not in the center of the scaner.")
#     194 # Center of the film
#     195 x0, y0 = zero_film_properties.centroid
#
# ValueError: The film is not in the center of the scaner.
